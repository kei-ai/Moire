# %% [markdown]
# <a href="https://colab.research.google.com/github/kei-ai/Moire/blob/main/Moire_ipynb_%E3%81%AE%E3%82%B3%E3%83%94%E3%83%BC.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !git clone https://github.com/NEETFUTURE/PyCUDA_MoireMethod
# %cd /content/PyCUDA_MoireMethod
# !pip install pycuda
# !python PyCUDA_MoireMethod.py
# Out:
# Cloning into 'PyCUDA_MoireMethod'...
# remote: Enumerating objects: 21, done.
# remote: Total 21 (delta 0), reused 0 (delta 0), pack-reused 21
# Unpacking objects: 100% (21/21), done.
# /content/PyCUDA_MoireMethod
# ...
#      |████████████████████████████████| 1.7MB 12.1MB/s
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#     Preparing wheel metadata ... done
# ...
#      |████████████████████████████████| 71kB 7.4MB/s
# ...
#      |████████████████████████████████| 81kB 7.9MB/s
# ...
#   Created wheel for pycuda: filename=pycuda-2021.1-cp37-cp37m-linux_x86_64.whl size=627305 sha256=47799e1349ea280a5aa57f5e72096ac900fd78817ee2904c4f5b02c1812d972a
#   Stored in directory: /root/.cache/pip/wheels/d5/55/64/fd4dddcc5f1c25eebd90b5291c3769101dc978c70165685512
# Successfully built pycuda
# ...
#   Created wheel for pytools: filename=pytools-2021.2.7-py2.py3-none-any.whl size=60644 sha256=54d413bf8facc79db87ca9ca698225ff2f9093b9153291f47281b63920853b98
# ...

# %%
#画像の出力
import os
from IPython.display import Image,display_png
for file in sorted(os.listdir()):
    base, ext = os.path.splitext(file)
    if ext == '.png':
        print(file)
        display_png(Image(file))
        print("\n\n\n\n")
# Out:
# input.png
# output.png
# phase00.png
# phase01.png
# phase02.png
# phase03.png
